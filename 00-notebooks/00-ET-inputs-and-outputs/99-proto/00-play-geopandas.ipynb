# %% [markdown]
# # Goals
#
# 1. prototype some pangeoLib functions
# 2. organize notebooks for inputs and output classification for ET
#
# ## prototype
# 1. boto 3 list all tiles
# 2. boto 3 list all outputs in tiles by subset
# 3. build coverage geometries for each tile day 001

# %%
import boto3

# %%
from pangeoLib.aws_authenticate import aws_authenticate

aws_authenticate()

# %%
# THIS code does not yet work with requestor pays - perhaps fsspec is much easier
def list_all_tiles():
    
    bucket = 'dev-et-data'
    #Make sure you provide / in the end
    prefix = 'tiles/'  

    client = boto3.client('s3')
    result = client.list_objects(Bucket=bucket, Prefix=prefix, Delimiter='/')
    for o in result.get('CommonPrefixes'):
        print ('sub folder : ', o.get('Prefix'))

# %%
#list_all_tiles()

# %%
! aws s3 ls --request-payer requester dev-et-data/tiles/
# Out:
#                            PRE t40N-80E/
#                            PRE tile40N-100E_chip32N-100E/
#                            PRE tile40N-100E_chip32N-92E/
#                            PRE tile40N-100E_chip32N-94E/
#                            PRE tile40N-100E_chip32N-96E/
#                            PRE tile40N-100E_chip32N-98E/
#                            PRE tile40N-100E_chip34N-100E/
#                            PRE tile40N-100E_chip34N-92E/
#                            PRE tile40N-100E_chip34N-94E/
#                            PRE tile40N-100E_chip34N-96E/
#                            PRE tile40N-100E_chip34N-98E/
#                            PRE tile40N-100E_chip36N-100E/
#                            PRE tile40N-100E_chip36N-92E/
#                            PRE tile40N-100E_chip36N-94E/
#                            PRE tile40N-100E_chip36N-96E/
#                            PRE tile40N-100E_chip36N-98E/
#                            PRE tile40N-100E_chip38N-100E/
#                            PRE tile40N-100E_chip38N-92E/
#                            PRE tile40N-100E_chip38N-94E/
#                            PRE tile40N-100E_chip38N-96E/
#                            PRE tile40N-100E_chip38N-98E/
#                            PRE tile40N-100E_chip40N-100E/
#                            PRE tile40N-100E_chip40N-92E/
#                            PRE tile40N-100E_chip40N-94E/
#                            PRE tile40N-100E_chip40N-96E/
#                            PRE tile40N-100E_chip40N-98E/
#                            PRE tile40N-110E/
#                            PRE tile40N-110E_chip32N-102E/
#                            PRE tile40N-110E_chip32N-102E_o/
#                            PRE tile40N-110E_chip32N-104E/
#                            PRE tile40N-110E_chip32N-104E_o/
#                            PRE tile40N-110E_chip32N-106E/
#                            PRE tile40N-110E_chip32N-106E_o/
#                            PRE tile40N-110E_chip32N-108E/
#                            PRE tile40N-110E_chip32N-108E_o/
#                            PRE tile40N-110E_chip32N-110E/
#                            PRE tile40N-110E_chip32N-110E_o/
#                            PRE tile40N-110E_chip34N-102E/
#                            PRE tile40N-110E_chip34N-102E_o/
#                            PRE tile40N-110E_chip34N-104E/
#                            PRE tile40N-110E_chip34N-104E_o/
#                            PRE tile40N-110E_chip34N-106E/
#                            PRE tile40N-110E_chip34N-106E_o/
#                            PRE tile40N-110E_chip34N-108E/
#                            PRE tile40N-110E_chip34N-108E_o/
#                            PRE tile40N-110E_chip34N-110E/
#                            PRE tile40N-110E_chip34N-110E_o/
#                            PRE tile40N-110E_chip36N-102E/
#                            PRE tile40N-110E_chip36N-102E_o/
#                            PRE tile40N-110E_chip36N-104E/
#                            PRE tile40N-110E_chip36N-104E_o/
#                            PRE tile40N-110E_chip36N-106E/
#                            PRE tile40N-110E_chip36N-106E_o/
#                            PRE tile40N-110E_chip36N-108E/
#                            PRE tile40N-110E_chip36N-108E_o/
#                            PRE tile40N-110E_chip36N-110E/
#                            PRE tile40N-110E_chip36N-110E_o/
#                            PRE tile40N-110E_chip38N-102E/
#                            PRE tile40N-110E_chip38N-102E_o/
#                            PRE tile40N-110E_chip38N-104E/
#                            PRE tile40N-110E_chip38N-104E_o/
#                            PRE tile40N-110E_chip38N-106E/
#                            PRE tile40N-110E_chip38N-106E_o/
#                            PRE tile40N-110E_chip38N-108E/
#                            PRE tile40N-110E_chip38N-108E_o/
#                            PRE tile40N-110E_chip38N-110E/
#                            PRE tile40N-110E_chip38N-110E_o/
#                            PRE tile40N-110E_chip40N-102E/
#                            PRE tile40N-110E_chip40N-102E_o/
#                            PRE tile40N-110E_chip40N-104E/
#                            PRE tile40N-110E_chip40N-104E_o/
#                            PRE tile40N-110E_chip40N-106E/
#                            PRE tile40N-110E_chip40N-106E_o/
#                            PRE tile40N-110E_chip40N-108E/
#                            PRE tile40N-110E_chip40N-108E_o/
#                            PRE tile40N-110E_chip40N-110E/
#                            PRE tile40N-110E_chip40N-110E_o/
#                            PRE tile40N-80E_chip32N-72E/
#                            PRE tile40N-80E_chip32N-74E/
#                            PRE tile40N-80E_chip32N-76E/
#                            PRE tile40N-80E_chip32N-78E/
#                            PRE tile40N-80E_chip32N-80E/
#                            PRE tile40N-80E_chip34N-72E/
#                            PRE tile40N-80E_chip34N-74E/
#                            PRE tile40N-80E_chip34N-76E/
#                            PRE tile40N-80E_chip34N-78E/
#                            PRE tile40N-80E_chip34N-80E/
#                            PRE tile40N-80E_chip36N-72E/
#                            PRE tile40N-80E_chip36N-74E/
#                            PRE tile40N-80E_chip36N-76E/
#                            PRE tile40N-80E_chip36N-78E/
#                            PRE tile40N-80E_chip36N-80E/
#                            PRE tile40N-80E_chip38N-72E/
#                            PRE tile40N-80E_chip38N-74E/
#                            PRE tile40N-80E_chip38N-76E/
#                            PRE tile40N-80E_chip38N-78E/
#                            PRE tile40N-80E_chip38N-80E/
#                            PRE tile40N-80E_chip40N-72E/
#                            PRE tile40N-80E_chip40N-74E/
#                            PRE tile40N-80E_chip40N-76E/
#                            PRE tile40N-80E_chip40N-78E/
#                            PRE tile40N-80E_chip40N-80E/
#                            PRE tile40N-90E_chip32N-82E/
#                            PRE tile40N-90E_chip32N-84E/
#                            PRE tile40N-90E_chip32N-86E/
#                            PRE tile40N-90E_chip32N-88E/
#                            PRE tile40N-90E_chip32N-90E/
#                            PRE tile40N-90E_chip34N-82E/
#                            PRE tile40N-90E_chip34N-84E/
#                            PRE tile40N-90E_chip34N-86E/
#                            PRE tile40N-90E_chip34N-88E/
#                            PRE tile40N-90E_chip34N-90E/
#                            PRE tile40N-90E_chip36N-82E/
#                            PRE tile40N-90E_chip36N-84E/
#                            PRE tile40N-90E_chip36N-86E/
#                            PRE tile40N-90E_chip36N-88E/
#                            PRE tile40N-90E_chip36N-90E/
#                            PRE tile40N-90E_chip38N-82E/
#                            PRE tile40N-90E_chip38N-84E/
#                            PRE tile40N-90E_chip38N-86E/
#                            PRE tile40N-90E_chip38N-88E/
#                            PRE tile40N-90E_chip38N-90E/
#                            PRE tile40N-90E_chip40N-82E/
#                            PRE tile40N-90E_chip40N-84E/
#                            PRE tile40N-90E_chip40N-86E/
#                            PRE tile40N-90E_chip40N-88E/
#                            PRE tile40N-90E_chip40N-90E/

# %%
aws_authenticate()

# %%
! rio info /vsis3/dev-et-data/test/compressed/NDVI_filled/2001/2001001.250_m_NDVI.tif
# Out:
# {"blockxsize": 512, "blockysize": 512, "bounds": [-155.57238265799998, 20.000239124000082, -52.215132156499976, 49.999999996000085], "colorinterp": ["gray"], "compress": "deflate", "count": 1, "crs": "EPSG:4326", "descriptions": [null], "driver": "GTiff", "dtype": "float32", "height": 14416, "indexes": [1], "interleave": "band", "lnglat": [-103.89375740724998, 35.00011956000009], "mask_flags": [["nodata"]], "nodata": -3.4028234663852886e+38, "res": [0.0020810045, 0.0020810045], "shape": [14416, 49667], "tiled": true, "transform": [0.0020810045, 0.0, -155.57238265799998, 0.0, -0.0020810045, 49.999999996000085, 0.0, 0.0, 1.0], "units": [null], "width": 49667}

# %%
import fsspec
fs = fsspec.filesystem('s3', anon=False, requester_pays=True)
chip_list = fs.ls('dev-et-data/tiles/')

# %%
! rio info /vsis3/dev-et-data/tiles/tile40N-100E_chip32N-100E/dd_2014.tif
# Out:
# {"bounds": [-100.00123780499997, 29.999468047915045, -97.99931147599997, 32.001394376915044], "colorinterp": ["gray"], "count": 1, "crs": "EPSG:4326", "descriptions": [null], "driver": "GTiff", "dtype": "float64", "height": 962, "indexes": [1], "interleave": "band", "lnglat": [-99.00027464049998, 31.000431212415045], "mask_flags": [["all_valid"]], "nodata": null, "res": [0.0020810045, 0.0020810045], "shape": [962, 962], "tiled": false, "transform": [0.0020810045, 0.0, -100.00123780499997, 0.0, -0.0020810045, 32.001394376915044, 0.0, 0.0, 1.0], "units": [null], "width": 962}

# %%
import rasterio
file='/vsis3/dev-et-data/tiles/tile40N-100E_chip32N-100E/dd_2014.tif'
src = rasterio.open(file)
src.shape
# Out:
# (962, 962)

# %%
#dir(src)

src.bounds.left
# Out:
# -100.00123780499997

# %%
dir(src.bounds)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_field_defaults',
#  '_fields',
#  '_fields_defaults',
#  '_make',
#  '_replace',
#  'bottom',
#  'count',
#  'index',
#  'left',
#  'right',
#  'top']

# %% [markdown]
# You are almost there with what you tried, and using the box method is indeed the best way. With the list comprehension, you can do
#
# b = [box(l, b, r, t) for l, b, r, t in zip(df.left, df.bottom, df.right, df.top)]
#
# Another option is to apply the box function to each row of your dataframe:
#
# b = df.apply(lambda row: box(row.left, row.bottom, row.right, row.top), axis=1)
#
# Once you have converted the bounding boxes to polygons, make sure to actually create a GeoDataFrame:
#
# gdf = geopandas.GeoDataFrame(df, geometry=b)

# %%
chip_list
# Out:
# ['dev-et-data/tiles/t40N-80E',
#  'dev-et-data/tiles/tile40N-100E_chip32N-100E',
#  'dev-et-data/tiles/tile40N-100E_chip32N-92E',
#  'dev-et-data/tiles/tile40N-90E_chip32N-86E',
#  'dev-et-data/tiles/tile40N-90E_chip32N-88E',
#  'dev-et-data/tiles/tile40N-90E_chip32N-90E',
#  'dev-et-data/tiles/tile40N-90E_chip34N-82E',
#  'dev-et-data/tiles/tile40N-90E_chip34N-84E',
#  'dev-et-data/tiles/tile40N-90E_chip34N-86E',
#  'dev-et-data/tiles/tile40N-90E_chip34N-88E',
#  'dev-et-data/tiles/tile40N-90E_chip34N-90E',
#  'dev-et-data/tiles/tile40N-90E_chip36N-82E',
#  'dev-et-data/tiles/tile40N-90E_chip36N-84E',
#  'dev-et-data/tiles/tile40N-90E_chip36N-86E',
#  'dev-et-data/tiles/tile40N-90E_chip36N-88E',
#  'dev-et-data/tiles/tile40N-90E_chip36N-90E',
#  'dev-et-data/tiles/tile40N-90E_chip38N-82E',
#  'dev-et-data/tiles/tile40N-90E_chip38N-84E',
#  'dev-et-data/tiles/tile40N-90E_chip38N-86E',
#  'dev-et-data/tiles/tile40N-90E_chip38N-88E',
#  'dev-et-data/tiles/tile40N-90E_chip38N-90E',
#  'dev-et-data/tiles/tile40N-90E_chip40N-82E',
#  'dev-et-data/tiles/tile40N-90E_chip40N-84E',
#  'dev-et-data/tiles/tile40N-90E_chip40N-86E',
#  'dev-et-data/tiles/tile40N-90E_chip40N-88E',
#  'dev-et-data/tiles/tile40N-90E_chip40N-90E']

# %%
def get_bounding(file):
    try:
        src = rasterio.open(file)
        return(src.bounds)
    except:
        pass

# %%
import pandas as pd
df = pd.DataFrame(columns=('Chip', 'left', 'bottom', 'right', 'top'))
i=0
for chip in chip_list:
    file = '/vsis3/' + chip + '/dd_2013.tif'
    bounds = get_bounding(file)
    if not bounds is None:
        print(bounds.left)
        df.loc[i] =[chip, bounds.left, bounds.bottom, bounds.right, bounds.top]
        i=i+1
# Out:
# -100.00123780499997
# -92.00185650699997
# -94.00170183149997
# -96.00154715599997
# -98.00139248049997
# -100.00123780499997
# -92.00185650699997
# -94.00170183149997
# -96.00154715599997
# -98.00139248049997
# -100.00123780499997
# -92.00185650699997
# -94.00170183149997
# -96.00154715599997
# -98.00139248049997
# -100.00123780499997
# -92.00185650699997
# -94.00170183149997
# -96.00154715599997
# -98.00139248049997
# -100.00123780499997
# -92.00185650699997
# -94.00170183149997
# -96.00154715599997
# -98.00139248049997
# -102.00108312949997
# -102.00108312949997
# -104.00092845399998
# -104.00092845399998
# -106.00077377849998
# -106.00077377849998
# -108.00061910299996
# -108.00061910299996
# -110.00046442749996
# -110.00046442749996
# -102.00108312949997
# -102.00108312949997
# -104.00092845399998
# -104.00092845399998
# -106.00077377849998
# -106.00077377849998
# -108.00061910299996
# -108.00061910299996
# -110.00046442749996
# -110.00046442749996
# -102.00108312949997
# -102.00108312949997
# -104.00092845399998
# -104.00092845399998
# -106.00077377849998
# -106.00077377849998
# -108.00061910299996
# -108.00061910299996
# -110.00046442749996
# -110.00046442749996
# -102.00108312949997
# -102.00108312949997
# -104.00092845399998
# -104.00092845399998
# -106.00077377849998
# -106.00077377849998
# -108.00061910299996
# 22     dev-et-data/tiles/tile40N-100E_chip40N-94E  -94.001702  37.998849
# 23     dev-et-data/tiles/tile40N-100E_chip40N-96E  -96.001547  37.998849
# 24     dev-et-data/tiles/tile40N-100E_chip40N-98E  -98.001392  37.998849
# 25    dev-et-data/tiles/tile40N-110E_chip32N-102E -102.001083  29.999468
# 26  dev-et-data/tiles/tile40N-110E_chip32N-102E_o -102.001083  29.999468
# 27    dev-et-data/tiles/tile40N-110E_chip32N-104E -104.000928  29.999468
# 28  dev-et-data/tiles/tile40N-110E_chip32N-104E_o -104.000928  29.999468
# 29    dev-et-data/tiles/tile40N-110E_chip32N-106E -106.000774  29.999468
#
#          right        top
# 0   -97.999311  32.001394
# 1   -89.999930  32.001394
# 2   -91.999776  32.001394
# 3   -93.999621  32.001394
# 4   -95.999466  32.001394
# 5   -97.999311  34.001240
# 6   -89.999930  34.001240
# 7   -91.999776  34.001240
# 8   -93.999621  34.001240
# 9   -95.999466  34.001240
# 10  -97.999311  36.001085
# 11  -89.999930  36.001085
# 12  -91.999776  36.001085
# 13  -93.999621  36.001085
# 14  -95.999466  36.001085
# 15  -97.999311  38.000930
# 16  -89.999930  38.000930
# 17  -91.999776  38.000930
# 18  -93.999621  38.000930
# 19  -95.999466  38.000930
# 20  -97.999311  40.000776
# 21  -89.999930  40.000776
# 22  -91.999776  40.000776
# 23  -93.999621  40.000776
# 24  -95.999466  40.000776
# 25  -99.999157  32.001394
# 26  -99.999157  32.001394
# 27 -101.999002  32.001394
# 28 -101.999002  32.001394
# 29 -103.998847  32.001394

# %%
dir(df)
# Out:
# ['Chip',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_box_item_values',
#  '_builtin_table',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_combine_match_index',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_create_indexer',
#  '_cython_table',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_from_axes',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_iget_item_cache',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_get_values',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_datelike_mixed_type',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'between_time',
#  'bfill',
#  'bool',
#  'bottom',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'left',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'right',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'top',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
df.describe()
# Out:
#              left      bottom       right         top
# count  125.000000  125.000000  125.000000  125.000000
# mean   -94.000953   33.999159  -91.998943   36.001085
# std     12.048236    2.839590   12.048264    2.839590
# min   -110.000464   29.999468 -107.998538   32.001394
# 25%   -104.000928   31.999313 -101.999002   34.001240
# 50%    -96.001547   33.999159  -93.999621   36.001085
# 75%    -84.000394   35.999004  -81.998468   38.000930
# max    -72.001322   37.998849  -69.999396   40.000776

# %%
import geopandas
from shapely.geometry import box
#import shapely.bounding.box as box

#Once you have converted the bounding boxes to polygons, make sure to actually create a GeoDataFrame:
b = df.apply(lambda row: box(row.left, row.bottom, row.right, row.top), axis=1)
gdf = geopandas.GeoDataFrame(df, geometry=b)

# %%
gdf.head()
# Out:
#                                           Chip        left     bottom  \
# 0  dev-et-data/tiles/tile40N-100E_chip32N-100E -100.001238  29.999468
# 1   dev-et-data/tiles/tile40N-100E_chip32N-92E  -92.001857  29.999468
# 2   dev-et-data/tiles/tile40N-100E_chip32N-94E  -94.001702  29.999468
# 3   dev-et-data/tiles/tile40N-100E_chip32N-96E  -96.001547  29.999468
# 4   dev-et-data/tiles/tile40N-100E_chip32N-98E  -98.001392  29.999468
#
#        right        top                                           geometry
# 0 -97.999311  32.001394  POLYGON ((-97.99931 29.99947, -97.99931 32.001...
# 1 -89.999930  32.001394  POLYGON ((-89.99993 29.99947, -89.99993 32.001...
# 2 -91.999776  32.001394  POLYGON ((-91.99978 29.99947, -91.99978 32.001...
# 3 -93.999621  32.001394  POLYGON ((-93.99962 29.99947, -93.99962 32.001...
# 4 -95.999466  32.001394  POLYGON ((-95.99947 29.99947, -95.99947 32.001...

# %%
import folium

# %%
tony_plot_tiles_json = gdf.to_json()

# %%
map_osm = folium.Map(location=[35, -90], zoom_start=5)

tile_boxes=folium.features.GeoJson(tony_plot_tiles_json)
map_osm.add_child(tile_boxes)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_s= gdf.loc[0]

#print(dir(my_s))


print(my_s.geometry)
# Out:
# POLYGON ((-97.99931147599997 29.99946804791504, -97.99931147599997 32.00139437691504, -100.001237805 32.00139437691504, -100.001237805 29.99946804791504, -97.99931147599997 29.99946804791504))

# %%
geopandas.GeoSeries([my_s.geometry]).to_json()
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[-97.99931147599997, 29.999468047915045], [-97.99931147599997, 32.001394376915044], [-100.00123780499997, 32.001394376915044], [-100.00123780499997, 29.999468047915045], [-97.99931147599997, 29.999468047915045]]]}, "bbox": [-100.00123780499997, 29.999468047915045, -97.99931147599997, 32.001394376915044]}], "bbox": [-100.00123780499997, 29.999468047915045, -97.99931147599997, 32.001394376915044]}'

# %%
map_osm = folium.Map(location=[35, -90], zoom_start=5)

style_function = lambda x: {'fillColor': 'red', 'color': 'green'} 

for index, row in gdf.iterrows():
    print(row.geometry)
    print(row.Chip)
    my_useful_geojson = geopandas.GeoSeries([row.geometry]).to_json()
    gjson = folium.GeoJson(my_useful_geojson, style_function=style_function, tooltip=row.Chip).add_to(map_osm)



map_osm
# Out:
# POLYGON ((-97.99931147599997 29.99946804791504, -97.99931147599997 32.00139437691504, -100.001237805 32.00139437691504, -100.001237805 29.99946804791504, -97.99931147599997 29.99946804791504))
# dev-et-data/tiles/tile40N-100E_chip32N-100E
# POLYGON ((-89.99993017799997 29.99946804791504, -89.99993017799997 32.00139437691504, -92.00185650699997 32.00139437691504, -92.00185650699997 29.99946804791504, -89.99993017799997 29.99946804791504))
# dev-et-data/tiles/tile40N-100E_chip32N-92E
# POLYGON ((-91.99977550249997 29.99946804791504, -91.99977550249997 32.00139437691504, -94.00170183149997 32.00139437691504, -94.00170183149997 29.99946804791504, -91.99977550249997 29.99946804791504))
# dev-et-data/tiles/tile40N-100E_chip32N-94E
# dev-et-data/tiles/tile40N-90E_chip40N-84E
# POLYGON ((-83.99831319999997 37.99884934591505, -83.99831319999997 40.00077567491505, -86.00023952899997 40.00077567491505, -86.00023952899997 37.99884934591505, -83.99831319999997 37.99884934591505))
# dev-et-data/tiles/tile40N-90E_chip40N-86E
# POLYGON ((-85.99815852449997 37.99884934591505, -85.99815852449997 40.00077567491505, -88.00008485349997 40.00077567491505, -88.00008485349997 37.99884934591505, -85.99815852449997 37.99884934591505))
# dev-et-data/tiles/tile40N-90E_chip40N-88E
# POLYGON ((-87.99800384899997 37.99884934591505, -87.99800384899997 40.00077567491505, -90.00201118249997 40.00077567491505, -90.00201118249997 37.99884934591505, -87.99800384899997 37.99884934591505))
# dev-et-data/tiles/tile40N-90E_chip40N-90E
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
my_s= gdf.loc[0]

# %%
print(my_s)
# Out:
# Chip              dev-et-data/tiles/tile40N-100E_chip32N-100E
# left                                                 -100.001
# bottom                                                29.9995
# right                                                -97.9993
# top                                                   32.0014
# geometry    POLYGON ((-97.99931147599997 29.99946804791504...
# Name: 0, dtype: object

# %%
my_gdf = geopandas.GeoDataFrame(my_s, geometry = [[my_s.geometry,]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-a5d19cbdf5e0> in <module>
# ----> 1 my_gdf = geopandas.GeoDataFrame(my_s, geometry = [[my_s.geometry,]])
#
# /srv/conda/envs/pangeo/lib/python3.7/site-packages/geopandas/geodataframe.py in __init__(self, *args, **kwargs)
#      87
#      88         if geometry is not None:
# ---> 89             self.set_geometry(geometry, inplace=True)
#      90         self._invalidate_sindex()
#      91
#
# /srv/conda/envs/pangeo/lib/python3.7/site-packages/geopandas/geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     179
#     180         # Check that we are using a listlike of geometries
# --> 181         level = _ensure_geometry(level)
#     182         index = frame.index
#     183         frame[geo_column_name] = level
#
# /srv/conda/envs/pangeo/lib/python3.7/site-packages/geopandas/geodataframe.py in _ensure_geometry(data)
#      32             return GeoSeries(out, index=data.index, name=data.name)
#      33         else:
# ---> 34             out = from_shapely(data)
#      35             return out
#      36
#
# /srv/conda/envs/pangeo/lib/python3.7/site-packages/geopandas/array.py in from_shapely(data)
#      88             out.append(None)
#      89         else:
# ---> 90             raise TypeError("Input must be valid geometry objects: {0}".format(geom))
#      91
#      92     aout = np.empty(n, dtype=object)
#
# TypeError: Input must be valid geometry objects: [<shapely.geometry.polygon.Polygon object at 0x7f74414ca1d0>]

# %%
#a=my_gdf.to_json()

type(my_gdf)

# %%
a_json = my_gdf.to_json()

# %%
from geojson import Polygon

# %%
print(my_s.geometry)

# %%
Polygon(my_s.geometry)

# %%
dir(my_s.geometry)

# %%
my_s.geometry.bounds

# %%
my_s.geometry.coords()

# %%
print(my_s.geometry.boundary)

# %%
dir(my_s.geometry.boundary)

# %%
from geojson import LineString

LineString(my_s.geometry.boundary)

# %%
print(my_s.geometry.boundary.xy)

# %%
LineString((-103.9988474495 33.99915869691505, -103.9988474495 36.00108502591505, -106.0007737785 36.00108502591505, -106.0007737785 33.99915869691505, -103.9988474495 33.99915869691505))

# %%
for index, row in gdf.iterrows():
    print(row)
    print(row.values)

# %%
dir(row)
