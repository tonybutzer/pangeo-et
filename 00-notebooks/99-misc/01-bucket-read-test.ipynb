# %%
! conda list
# Out:
# # packages in environment at /srv/conda/envs/notebook:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main    conda-forge
# adal                      1.2.2                      py_0    conda-forge
# affine                    2.3.0                      py_0    conda-forge
# aiohttp                   3.6.2            py37h516909a_0    conda-forge
# alembic                   1.3.2                      py_0    conda-forge
# antlr-python-runtime      4.7.2                 py37_1000    conda-forge
# appdirs                   1.4.3                      py_1    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# async-timeout             3.0.1                   py_1000    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrdict                  2.0.1                      py_0    conda-forge
# ...

# %%
! aws s3 ls
# Out:
# /bin/sh: 1: aws: not found

# %%
! pip list |grep boto
# Out:
# boto3                  1.10.39
# botocore               1.13.39

# %%
# !pip install --user awscli
# Out:
# ...
#      |████████████████████████████████| 2.9MB 3.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 51kB 568kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 1.0MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 5.9MB 49.7MB/s eta 0:00:01
# ...
# ERROR: boto3 1.10.39 has requirement botocore<1.14.0,>=1.13.39, but you'll have botocore 1.14.15 which is incompatible.
# ERROR: boto3 1.10.39 has requirement s3transfer<0.3.0,>=0.2.0, but you'll have s3transfer 0.3.3 which is incompatible.
# ...

# %%
! aws s3 ls
# Out:
# 2019-09-19 16:05:41 cf-templates-1idkatmbgn6dx-us-west-2
# 2019-09-19 16:09:39 csr-adminbucket-376067480372
# 2020-02-10 19:28:09 earthmap-pangeo-kubeconfigbucket-1bhpejwku7fa1
# 2019-12-18 17:41:58 pangeo-lidar-demo
# 2019-12-17 22:07:07 pangeo-s3-demo-bucket
# 2019-11-22 17:37:07 pangeo-scripts-bucket

# %%
# !aws s3 ls dev-usgs-landsat
# Out:
#                            PRE collection-01/
#                            PRE collection01/
#                            PRE collection02/
#                            PRE collection1/
#                            PRE gls_collection2/
#                            PRE i-t-testdata/
# 2020-01-21 16:04:57        575 catalog.json

# %%
# !aws s3 ls dev-usgs-landsat/collection1/level2/albers/oli-tirs/2018/046/028/
# Out:
#                            PRE LC08_L1GT_046028_20180412_20180417_01_A2/
#                            PRE LC08_L1GT_046028_20181005_20181010_01_A2/
#                            PRE LC08_L1GT_046028_20181122_20181129_01_A2/
#                            PRE LC08_L1TP_046028_20180106_20180120_01_A1/
#                            PRE LC08_L1TP_046028_20180122_20180207_01_A1/
#                            PRE LC08_L1TP_046028_20180207_20180222_01_A1/
#                            PRE LC08_L1TP_046028_20180223_20180309_01_A1/
#                            PRE LC08_L1TP_046028_20180311_20180321_01_A1/
#                            PRE LC08_L1TP_046028_20180327_20180405_01_A1/
#                            PRE LC08_L1TP_046028_20180428_20180502_01_A1/
#                            PRE LC08_L1TP_046028_20180514_20180605_01_A1/
#                            PRE LC08_L1TP_046028_20180530_20180615_01_A1/
#                            PRE LC08_L1TP_046028_20180615_20180704_01_A1/
# ...

# %%
# !aws s3 ls dev-usgs-landsat/collection1/level2/albers/oli-tirs/2018/046/028/LC08_L1TP_046028_20180106_20180120_01_A1/
# Out:
# 2019-09-10 19:10:38      28026 LC08_L1TP_046028_20180106_20180120_01_A1.json
# 2019-09-10 19:10:24      34426 LC08_L1TP_046028_20180106_20180120_01_A1.xml
# 2019-09-10 19:10:38     104934 LC08_L1TP_046028_20180106_20180120_01_A1_ANG.json
# 2019-09-10 19:10:20     117413 LC08_L1TP_046028_20180106_20180120_01_A1_ANG.txt
# 2019-09-10 19:10:39       9214 LC08_L1TP_046028_20180106_20180120_01_A1_BT_stac.json
# 2019-09-10 19:10:38       8317 LC08_L1TP_046028_20180106_20180120_01_A1_MTL.json
# 2019-09-10 19:10:28       8807 LC08_L1TP_046028_20180106_20180120_01_A1_MTL.txt
# 2019-11-14 19:23:17      10024 LC08_L1TP_046028_20180106_20180120_01_A1_SR_stac.json
# 2019-09-10 19:10:39       9214 LC08_L1TP_046028_20180106_20180120_01_A1_ST_stac.json
# 2019-09-10 19:10:39       9214 LC08_L1TP_046028_20180106_20180120_01_A1_TA_stac.json
# 2019-09-10 19:10:24   26449552 LC08_L1TP_046028_20180106_20180120_01_A1_bt_band10.tif
# ...

# %%
# !aws s3 cp s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2018/046/028/LC08_L1TP_046028_20180106_20180120_01_A1/LC08_L1TP_046028_20180106_20180120_01_A1_thumb_large.jpeg .
# Out:
# download: s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2018/046/028/LC08_L1TP_046028_20180106_20180120_01_A1/LC08_L1TP_046028_20180106_20180120_01_A1_thumb_large.jpeg to ./LC08_L1TP_046028_20180106_20180120_01_A1_thumb_large.jpeg

# %% [markdown]
# ![thumb](./LC08_L1TP_046028_20180106_20180120_01_A1_thumb_large.jpeg)

# %%
! ip a
# Out:
# /bin/sh: 1: ip: not found

# %%
! ifconfig -a
# Out:
# /bin/sh: 1: ifconfig: not found

# %%
! curl --help
# Out:
# Usage: curl [options...] <url>
#      --abstract-unix-socket <path> Connect via abstract Unix domain socket
#      --alt-svc <file name> Enable alt-svc with this cache file
#      --anyauth       Pick any authentication method
#  -a, --append        Append to target file when uploading
#      --basic         Use HTTP Basic Authentication
#      --cacert <file> CA certificate to verify peer against
#      --capath <dir>  CA directory to verify peer against
#  -E, --cert <certificate[:password]> Client certificate file and password
#      --cert-status   Verify the status of the server certificate
#      --cert-type <type> Certificate file type (DER/PEM/ENG)
#      --ciphers <list of ciphers> SSL ciphers to use
#      --compressed    Request compressed response
#      --compressed-ssh Enable SSH compression
#  -K, --config <file> Read config from a file
#      --connect-timeout <seconds> Maximum time allowed for connection
#      --connect-to <HOST1:PORT1:HOST2:PORT2> Connect to host
# ...
