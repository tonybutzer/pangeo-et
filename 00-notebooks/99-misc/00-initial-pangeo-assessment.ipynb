# %%
! conda list
# Out:
# # packages in environment at /srv/conda/envs/pangeo:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                      1_llvm    conda-forge
# adal                      1.2.2                      py_0    conda-forge
# affine                    2.3.0                      py_0    conda-forge
# aiofiles                  0.5.0                      py_0    conda-forge
# aiohttp                   3.6.2            py37h516909a_0    conda-forge
# alembic                   1.4.2              pyh9f0ad1d_0    conda-forge
# antlr-python-runtime      4.7.2                 py37_1001    conda-forge
# appdirs                   1.4.3                      py_1    conda-forge
# asciitree                 0.3.3                      py_2    conda-forge
# asn1crypto                1.3.0                    py37_0    conda-forge
# ...

# %%
# !ls
# Out:
# 00-initial-pangeo-assessment.ipynb
# 01-bucket-read-test.ipynb
# LC08_L1TP_046028_20180106_20180120_01_A1_thumb_large.jpeg
# notebook

# %%
# !pwd
# Out:
# /home/jovyan

# %%
! mkdir opt

# %%
! (cd opt; git clone http://github.com/tonybutzer/notebook)
# Out:
# Cloning into 'notebook'...
# ...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 1148 (delta 63), reused 94 (delta 28), pack-reused 1009
# Receiving objects: 100% (1148/1148), 335.40 MiB | 48.99 MiB/s, done.
# Resolving deltas: 100% (436/436), done.
# Checking out files: 100% (532/532), done.

# %%
! aws s3 ls dev-et-data
# Out:
# An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
